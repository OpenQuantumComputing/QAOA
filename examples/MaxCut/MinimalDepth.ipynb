# %%
import matplotlib.pyplot as plt
import networkx as nx
import sys
sys.path.append("../")

from plotroutines import draw_colored_graph
from qaoa.util import *

G = nx.read_gml("data/er_n10_k4_0.gml")
graph = GraphHandler(G)

for color, edges in graph.parallel_edges.items():
    print(f"Color {color}: {edges}")
draw_colored_graph(graph.G, graph.parallel_edges)
# Out:
# Color 0: [(0, 1), (3, 8), (9, 4), (2, 7), (5, 6)]
# Color 1: [(5, 8), (3, 7), (2, 1), (9, 6)]
# Color 2: [(9, 5), (0, 3), (7, 1)]
# Color 3: [(3, 1), (0, 9), (4, 7), (2, 5)]
