# %%
import matplotlib.pyplot as plt
import networkx as nx
from qaoa import utils

G = nx.read_gml("data/er_n10_k4_0.gml")
graph = utils.GraphHandler(G)

for color, edges in graph.parallel_edges.items():
    print(f"Color {color}: {edges}")
utils.draw_colored_graph(graph.G, graph.parallel_edges)
# Out:
# Color 0: [(0, 1), (2, 5), (9, 6), (4, 7), (3, 8)]
# Color 1: [(9, 5), (7, 1), (0, 3)]
# Color 2: [(0, 9), (3, 1), (2, 7), (5, 6)]
# Color 3: [(3, 7), (5, 8), (9, 4), (2, 1)]
