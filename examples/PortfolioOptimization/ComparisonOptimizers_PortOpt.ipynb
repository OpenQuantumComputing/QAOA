# %% [markdown]
# # Comparisons of different optimizeers for QAOA (Portfolio Optimization)
# In this notebook different optimizers for the QAOA parameters are compared, for the problem of portfolio optimization. Both the values of the parameters and the resulting approximation ratio are compared. We try each optimizer for both the penalty method and the XY-mixer method of incorporating the fixed budget constraint.
# # Importing necessary modules

# %%
from qaoa import QAOA, problems, mixers

# %%
from asset_loader import AssetData
from utilities_portOpt import computeMinMaxCosts, computeAverageApproxRatio, approxRatio
from qiskit import *
import numpy as np
import matplotlib.pyplot as pl
from mpl_toolkits.axes_grid1 import make_axes_locatable
from qiskit.visualization import *
from qiskit_algorithms.optimizers import SPSA, QNSPSA, COBYLA, NELDER_MEAD

# %% [markdown]
# # Creating problem instance

# %%
number_of_assets = 12
budget = 6

filename = os.path.join("data", "qiskit_finance_seeds.npz")
seeds = np.load(filename)
assets = AssetData(number_of_assets, seed=seeds[str(number_of_assets)][132])

assets.plotAssets()
# Out:
# /home/franzf/OpenQuantumComputing/QAOA/examples/PortfolioOptimization/asset_loader.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=-30)

# %% [markdown]
# # Setting up the optimizers to use roughly the same number of function evaluations

# %%
optimizers={}
plotstyle={}

settings = {
    "maxiter": 70,
    "blocking": True,
    "allowed_increase": 0,
    "second_order": True,
    "regularization": 0.01
}
optimizers["spsa"] = [SPSA, settings.copy()]
plotstyle["spsa"] = '+-'

settings = {
    "maxiter": 50,
    "blocking": True,
    "allowed_increase": 0,
    "learning_rate": 0.02,
    "perturbation": 0.05,
    "regularization": 0.01,
    "hessian_delay": 0
}
optimizers["qnspsa"] = [QNSPSA, settings.copy()]
plotstyle["qnspsa"] = 'o-'

settings = {
    "maxiter": 110,
    "tol": 1e-6 
}
optimizers["neldermead"] = [NELDER_MEAD, settings.copy()]
plotstyle["neldermead"] = 'x-'

settings = {
    "maxiter": 350,
    "tol": 1e-6 
}
optimizers["cobyla"] = [COBYLA, settings.copy()]
plotstyle["cobyla"] = '*-'

# %% [markdown]
# # Creating QAOA instances (both penalty and XY-mixer method) for each optimizer
# Below we create a QAOA instance using the penalty method and one QAOA instance using the XY-mixer for each optimizer method.
# The gamma_scale parameter is used to adjust the search range for the gamma parameter.
#
# For information about the scale parameter see Sebastian Brandhofer et al. “Benchmarking the performance of portfolio optimization with QAOA”. In: Quantum Information Processing 22.1 (2023), page 25-26)
# or Zichang He et al. Alignment between Initial State and Mixer Improves QAOA Performance for
# Constrained Portfolio Optimization page 7 (2023)

# %%
gamma_scale = 5000 #Adjusts the search range for the gamma parameter 

params_penalty = {
    "risk" : 0.5*gamma_scale,
    "budget": budget,
    "penalty": 4*gamma_scale, #Use optimal penalty?????
    "cov_matrix": assets.cov_matrix,
    "exp_return": assets.exp_return*gamma_scale,
    "usebarrier": False #OBS: only set to true for drawing NOT for simulations
}

params_XYmixer = {
    "risk" : 0.5*gamma_scale,
    "budget": budget,
    "cov_matrix": assets.cov_matrix,
    "exp_return": assets.exp_return*gamma_scale,
    "usebarrier": False #OBS: only set to true for drawing NOT for simulations
}


qaoa_penalty = {}
qaoa_XYmixer = {}
for key in optimizers:
    params_penalty["optimizer"] = optimizers[key]
    qaoa_penalty[key] = QAOA(
        problem=problems.PortfolioOptimization,
        mixer=mixers.X,
        params=params_penalty
    )
    
    # QAOAPortfolioOptimization(params = params_penalty)
    # if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
    #     params_XYmixer["optimizer"] = optimizers[key]
    #     qaoa_XYmixer[key] = QAOAPortfolioOptimization_mixer(params = params_XYmixer)

# %% [markdown]
# # Sample cost landscape for each QAOA instance

# %%
for key in optimizers:
    qaoa_penalty[key].sample_cost_landscape(angles={"gamma": [0,np.pi/2,10], "beta": [0,np.pi/2,10]})
    # if key != "qnspsa": # QNSPSA does not work for the XY-method???
    #     qaoa_XYmixer[key].sample_cost_landscape(angles={"gamma": [0,np.pi/2,10], "beta": [0,2*np.pi,10]})
# Out:
# 2023-09-11 16:01:57 [info     ] Calculating energy landscape for depth p=1... file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:58 [info     ] Executing sample_cost_landscape file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:58 [info     ] parameters: 2                  file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:58 [info     ] Done execute                   file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:59 [info     ] Done measurement               file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:59 [info     ] Calculating Energy landscape done file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:59 [info     ] Calculating energy landscape for depth p=1... file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:59 [info     ] Executing sample_cost_landscape file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:59 [info     ] parameters: 2                  file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:01:59 [info     ] Done execute                   file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:00 [info     ] Done measurement               file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:00 [info     ] Calculating Energy landscape done file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:00 [info     ] Calculating energy landscape for depth p=1... file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:00 [info     ] Executing sample_cost_landscape file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:00 [info     ] parameters: 2                  file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:00 [info     ] Done execute                   file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:01 [info     ] Done measurement               file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:01 [info     ] Calculating Energy landscape done file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:01 [info     ] Calculating energy landscape for depth p=1... file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:01 [info     ] Executing sample_cost_landscape file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:01 [info     ] parameters: 2                  file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:01 [info     ] Done execute                   file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:02 [info     ] Done measurement               file=qaoa.qaoa func=sample_cost_landscape
# 2023-09-11 16:02:02 [info     ] Calculating Energy landscape done file=qaoa.qaoa func=sample_cost_landscape

# %% [markdown]
# # Plot the cost landscape for the penalty method
# The cost landscape is of course the same for all the optimizer methods and is plotted below, for the penalty method

# %%
method = "cobyla"

f = pl.figure(figsize=(6, 6), dpi= 80, facecolor='w', edgecolor='k');
_=pl.xlabel(r'$\gamma$')
_=pl.ylabel(r'$\beta$')
ax = pl.gca()
_=pl.title('Expectation value')
im = ax.imshow(qaoa_penalty[method].E,interpolation='bicubic',origin='lower',extent=[0,np.pi/2,0,np.pi/2])
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
_=pl.colorbar(im, cax=cax)

# %% [markdown]
# # Plot the cost landscape for the XY-mixer method, for one optimizer
# The cost landscape is of course the same for all the optimizer methods and is plotted below, for the XY-mixer method. Note that the beta range is different for for the penalty method and the XY-mixer method, due to different periods in the mixers.

# %%
method = "cobyla"

f = pl.figure(figsize=(6, 6), dpi= 80, facecolor='w', edgecolor='k');
_=pl.xlabel(r'$\gamma$')
_=pl.ylabel(r'$\beta$')
ax = pl.gca()
_=pl.title('Expectation value')
im = ax.imshow(qaoa_XYmixer[method].E,interpolation='bicubic',origin='lower',extent=[0,np.pi/2,0,2*np.pi])
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
_=pl.colorbar(im, cax=cax)

# %% [markdown]
# # Increasing depth for all QAOA instances

# %%
maxdepth=10
for i in range(maxdepth):
    for key in optimizers:
        qaoa_penalty[key].increase_depth()
        # if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
        #     qaoa_XYmixer[key].increase_depth()
# Out:
# 2023-09-11 16:02:24 [info     ] cost(depth 1 = 29966.60109939799 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:02:41 [info     ] cost(depth 1 = 33560.321739096784 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:02:48 [info     ] cost(depth 1 = 28012.82933430006 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:02:49 [info     ] cost(depth 1 = 36017.099387318274 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:03:01 [info     ] cost(depth 2 = 33975.4122632628 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:03:27 [info     ] cost(depth 2 = 47569.322147615814 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:03:36 [info     ] cost(depth 2 = 29268.156900041624 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:03:37 [info     ] cost(depth 2 = 35916.21579713004 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:03:53 [info     ] cost(depth 3 = 42888.180311157186 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:04:25 [info     ] cost(depth 3 = 58981.70170031207 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:04:36 [info     ] cost(depth 3 = 30856.24162028202 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:04:39 [info     ] cost(depth 3 = 46431.59012554196 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:04:57 [info     ] cost(depth 4 = 43786.705598718116 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:05:37 [info     ] cost(depth 4 = 60310.45546291717 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:05:52 [info     ] cost(depth 4 = 35397.550137196115 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:05:57 [info     ] cost(depth 4 = 41517.15243124671 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:06:19 [info     ] cost(depth 5 = 43006.31194401513 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:07:06 [info     ] cost(depth 5 = 62713.518417767365 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:07:21 [info     ] cost(depth 5 = 35440.45646385508 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:07:28 [info     ] cost(depth 5 = 49843.55322268749 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:07:54 [info     ] cost(depth 6 = 37044.67339543264 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:08:48 [info     ] cost(depth 6 = 56539.930291465156 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:09:08 [info     ] cost(depth 6 = 41146.79768701237 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:09:17 [info     ] cost(depth 6 = 56112.14487150275 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:09:47 [info     ] cost(depth 7 = 38695.3978732524 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:10:49 [info     ] cost(depth 7 = 61346.16640048589 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:11:12 [info     ] cost(depth 7 = 33941.856249947894 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:11:24 [info     ] cost(depth 7 = 56208.83070305279 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:11:58 [info     ] cost(depth 8 = 35875.3494890966 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:13:07 [info     ] cost(depth 8 = 58161.557040824904 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:13:41 [info     ] cost(depth 8 = 36517.85882722631 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:13:58 [info     ] cost(depth 8 = 58316.722530774096 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:14:39 [info     ] cost(depth 9 = 42728.09701269594 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:15:58 [info     ] cost(depth 9 = 54333.77878684978 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:16:31 [info     ] cost(depth 9 = 49861.329792383054 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:16:49 [info     ] cost(depth 9 = 56267.94203661141 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:17:35 [info     ] cost(depth 10 = 29934.016018540344 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:19:02 [info     ] cost(depth 10 = 58280.106037946345 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:19:51 [info     ] cost(depth 10 = 48396.87622720501 file=qaoa.qaoa func=increase_depth
# 2023-09-11 16:20:12 [info     ] cost(depth 10 = 57536.703312392965 file=qaoa.qaoa func=increase_depth

# %% [markdown]
# # Compute and print the optimal solution with minium cost

# %%
method = "cobyla"
cost_func = qaoa_penalty[method].cost 
isFeasible_func = qaoa_penalty[method].isFeasible 
#These function are the same for all methoods

min_cost, max_cost, solution = computeMinMaxCosts(number_of_assets, cost_func, isFeasible_func)
print("Optimal solution: ", solution, "\n With cost: ", min_cost)
# Out:
# Optimal solution:  100100101011
#  With cost:  -29.063041157787666

# %%
hists_penalty = {}
hists_XYmixer = {}


for key in optimizers:
    hists_penalty[key] = [qaoa_penalty[key].hist(qaoa_penalty[key].angles_hist['d'+str(1)+'_final'])]
    if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
        hists_XYmixer[key] = [qaoa_XYmixer[key].hist(qaoa_XYmixer[key].angles_hist['d'+str(1)+'_final'])]
    for i in range(1, maxdepth):
            hists_penalty[key].append(qaoa_penalty[key].hist(qaoa_penalty[key].angles_hist['d'+str(i+1)+'_final']))
            if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
                hists_XYmixer[key].append(qaoa_XYmixer[key].hist(qaoa_XYmixer[key].angles_hist['d'+str(i+1)+'_final']))



apprx_ratio_penalty = {} #List of approx ratios for different depths at each key in this dictionary
apprx_ratio_XYmixer = {} #List of approx ratios for different depths at each key in this dictionary

for key in optimizers: 
    apprx_ratio_penalty[key] = [computeAverageApproxRatio(hists_penalty[key][0], max_cost, min_cost, cost_func, isFeasible_func)]
    if key != "qnspsa":
        apprx_ratio_XYmixer[key] = [computeAverageApproxRatio(hists_penalty[key][0], max_cost, min_cost, cost_func, isFeasible_func)]   
    for i in range(1, maxdepth):
        apprx_ratio_penalty[key].append(computeAverageApproxRatio(hists_penalty[key][i], max_cost, min_cost, cost_func, isFeasible_func))
        if key != "qnspsa":
            apprx_ratio_XYmixer[key].append(computeAverageApproxRatio(hists_XYmixer[key][i], max_cost, min_cost, cost_func, isFeasible_func))


apprx_ratio_penalty2 = {}
apprx_ratio_XYmixer2 = {}
for key in optimizers:
    apprx_ratio_penalty2[key] = approxRatio(list(qaoa_penalty[key].costval.values()), max_cost, min_cost)
    if key != "qnspsa":
        apprx_ratio_XYmixer2[key] = approxRatio(list(qaoa_XYmixer[key].costval.values()), max_cost, min_cost)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 8
#       6 hists_penalty[key] = [qaoa_penalty[key].hist(qaoa_penalty[key].angles_hist['d'+str(1)+'_final'])]
#       7 if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
# ----> 8     hists_XYmixer[key] = [qaoa_XYmixer[key].hist(qaoa_XYmixer[key].angles_hist['d'+str(1)+'_final'])]
#       9 for i in range(1, maxdepth):
#      10         hists_penalty[key].append(qaoa_penalty[key].hist(qaoa_penalty[key].angles_hist['d'+str(i+1)+'_final']))
#
# KeyError: 'spsa'

# %% [markdown]
# # Plotting the approximation ratios using the penalty method for the different optimizers
# Below the approximation ratios are plotted for the different optimizers.

# %%
ax = pl.figure().gca()
pl.hlines(1, 1,maxdepth, linestyles="solid", colors="black")
for key in optimizers:
    pl.plot(np.arange(1,maxdepth+1), apprx_ratio_penalty[key], plotstyle[key], label=key)
pl.ylim(0,1.01)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('appr. ratio')
_=pl.xlabel('depth')
_=pl.legend(loc="lower right", framealpha=1)
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Plotting the approximation ratios using the penalty method the different optimizers (SECOND WAY)

# %%
ax = pl.figure().gca()
pl.hlines(1, 1,maxdepth, linestyles="solid", colors="black")
for key in optimizers:
    pl.plot(np.arange(1,maxdepth+1), apprx_ratio_penalty2[key], plotstyle[key], label=key)
pl.ylim(0,1.01)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('appr. ratio')
_=pl.xlabel('depth')
_=pl.legend(loc="lower right", framealpha=1)
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Plotting the approximation ratios using the XY-mixer method for the different optimizers
# Below the approximation ratios are plotted using the XY-mixer, for the different optimizers.

# %%
ax = pl.figure().gca()
pl.hlines(1, 1,maxdepth, linestyles="solid", colors="black")
for key in optimizers:
    if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
        pl.plot(np.arange(1,maxdepth+1), apprx_ratio_XYmixer[key], plotstyle[key], label=key)
pl.ylim(0,1.01)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('appr. ratio')
_=pl.xlabel('depth')
_=pl.legend(loc="lower right", framealpha=1)
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Plotting the approximation ratios using the XY-mixer method for the different optimizers (SECOND WAY)

# %%
ax = pl.figure().gca()
pl.hlines(1, 1,maxdepth, linestyles="solid", colors="black")
for key in optimizers:
    if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
        pl.plot(np.arange(1,maxdepth+1), apprx_ratio_XYmixer2[key], plotstyle[key], label=key)
pl.ylim(0,1.01)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('appr. ratio')
_=pl.xlabel('depth')
_=pl.legend(loc="lower right", framealpha=1)
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Plotting the values for the parameters for the penalty method
# Below we plot the values for $\gamma$ and $\beta$ parameters for the penalty method found by the different optimizers. One sees that...

# %%
ax = pl.figure().gca()
for key in optimizers:
    pl.plot(np.arange(1,maxdepth+1),qaoa_penalty[key].angles_hist['d'+str(maxdepth)+'_final'][::2],"b"+plotstyle[key],label='gamma '+key)
    pl.plot(np.arange(1,maxdepth+1),qaoa_penalty[key].angles_hist['d'+str(maxdepth)+'_final'][1::2],"g"+plotstyle[key],label='beta '+key)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('parameter')
_=pl.xlabel('depth')
_=pl.legend()
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Plotting the values for the parameters for the XY-mixer method
#
# Below we plot the values for $\gamma$ and $\beta$ parameters for the penalty method found by the different optimizers. One sees that...

# %%
ax = pl.figure().gca()
for key in optimizers:
    if key !="qnspsa": #qnspsa does not work for the XY-mixer method???
        pl.plot(np.arange(1,maxdepth+1),qaoa_XYmixer[key].angles_hist['d'+str(maxdepth)+'_final'][::2],"b"+plotstyle[key],label='gamma '+key)
        pl.plot(np.arange(1,maxdepth+1),qaoa_XYmixer[key].angles_hist['d'+str(maxdepth)+'_final'][1::2],"g"+plotstyle[key],label='beta '+key)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('parameter')
_=pl.xlabel('depth')
_=pl.legend()
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Plotting the number of function evaluations used by each optimizer for the penalty method
# Below the number of function evaluations used by the different optimizers are plotted for increasing depths, for the penalty method.

# %%
ax = pl.figure().gca()
for key in optimizers:
    _=pl.plot(np.arange(1,maxdepth+1),qaoa_penalty[key].num_fval.values(), plotstyle[key], label=key)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('number of function evaluations')
_=pl.xlabel('depth')
_=pl.legend()
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Plotting the numver of function evaluations used by each optimizer for the XY-mixer method
# Below the number of function evaluations used by the different optimizers are plotted for increasing depths, for the XY-mixer method.

# %%
ax = pl.figure().gca()
for key in optimizers:
    if key != "qnspsa": #qnspsa does not work for the XY-mixer method???
        _=pl.plot(np.arange(1,maxdepth+1),qaoa_XYmixer[key].num_fval.values(), plotstyle[key], label=key)
pl.xlim(1-.25,maxdepth+.25)
_=pl.ylabel('number of function evaluations')
_=pl.xlabel('depth')
_=pl.legend()
#ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# # Should a test be done with CVaR and different optimizers?
